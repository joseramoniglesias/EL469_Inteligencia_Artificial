# %% [markdown]
# # Proyecto - Asistente de IA para aerolíneas
#
# ## GEMINI 1.5 - uso de herramientas
#
# * https://cloud.google.com/vertex-ai/generative-ai/docs/multimodal/function-calling

# %%
# imports

import os
import json
from dotenv import load_dotenv
import gradio as gr
from google import genai
import google.genai.types as types

# %%
#import google.generativeai as genai

# Inicialización

load_dotenv()

google_api_key = os.getenv('GOOGLE_API_KEY','AIzaSyAV6da61UIyw12pOqeTdEQsENWmnjE5GaQ')

if google_api_key:
    print(f"Google API Key existe y empieza por {google_api_key[:8]}")
else:
    print("Google API Key Sin Configurar")

client = genai.Client(api_key="AIzaSyAV6da61UIyw12pOqeTdEQsENWmnjE5GaQ")
#"genai.configure(api_key= google_api_key)
# Out:
# Google API Key existe y empieza por no

# %% [markdown]
# ### Declaramos las herramientas

# %%
# https://github.com/google-gemini/cookbook/blob/main/quickstarts/Function_calling.ipynb

ticket_prices = {"londres": "799€", "parís": "899€", "tokyo": "1400€", "berlín": "499€"}

def contar(a: str):
    """returns result"""
    result= len(a)
    return result
    
def get_ticket_price(destination_city: str):
    """returns result"""
    print(f"Se solicitó la herramienta get_ticket_price para {destination_city}")
    city = destination_city.lower()
    result = ticket_prices.get(city, "Unknown")
    return result

def get_flight_price(city: str):
    """returns result"""
    print(f"Se solicitó la herramienta get_flight_price para {city}")
    city = city.lower()
    result = ticket_prices.get(city, "Unknown")
    return result

# %% [markdown]
# ### Personalizamos el comportamiento del modelo y referimos las herramientas

# %%
system_message = "Eres un asistente útil para una aerolínea llamada FlightAI. "
system_message += "Da respuestas breves y corteses, de no más de una oración. "
system_message += "Se siempre preciso. Si no sabes la respuesta, dilo."


response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Hello, world! Tell me a joke."
#model = genai.GenerativeModel(
 #   model_name="gemini-2.5-flash",
 #   system_instruction=system_message,
 #   tools=[contar, get_ticket_price, get_flight_price]
)

print (response)
# Out:
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""Hello, world! Here's one for you:
#
# Why don't scientists trust atoms?
#
# Because they make up everything!"""
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash' prompt_feedback=None response_id='udAEaa_0IfHVz7IPlK7o-Ao' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=27,
#   prompt_token_count=10,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=10
#     ),
#   ],
#   thoughts_token_count=47,
#   total_token_count=84
# ) automatic_function_calling_history=[] parsed=None

# %%
chat = client.chats.create(
    model="gemini-2.5-flash",  # Or "gemini-2.5-pro", etc.
    config=types.GenerateContentConfig(  # Optional: Customize temperature, etc.
        temperature=0.7,
        max_output_tokens=512
    )
)

# Send messages (appends to history automatically)
response = chat.send_message("Hello! Tell me a joke.")
print(response.text)

response = chat.send_message("Explain why that's funny.")
print(response.text)

# View full history
for message in chat.get_history():
    print(f"{message.role}: {message.parts[0].text}")

#chat= model.start_chat(enable_automatic_function_calling=True)

#response = chat.send_message("¿Cuál es el precio de un ticket a Londres?")
response.text
# Out:
# ---------------------------------------------------------------------------
# ServerError                               Traceback (most recent call last)
# Cell In[34], line 11
#       2 chat = client.chats.create(
#       3     model="gemini-2.5-flash",  # Or "gemini-2.5-pro", etc.
#       4     config=types.GenerateContentConfig(  # Optional: Customize temperature, etc.
#    (...)
#       7     )
#       8 )
#      10 # Send messages (appends to history automatically)
# ---> 11 response = chat.send_message("Hello! Tell me a joke.")
#      12 print(response.text)
#      14 response = chat.send_message("Explain why that's funny.")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\genai\chats.py:254, in Chat.send_message(self, message, config)
#     249   raise ValueError(
#     250       f"Message must be a valid part type: {types.PartUnion} or"
#     251       f" {types.PartUnionDict}, got {type(message)}"
#     252   )
#     253 input_content = t.t_content(message)
# --> 254 response = self._modules.generate_content(
#     255     model=self._model,
#     256     contents=self._curated_history + [input_content],  # type: ignore[arg-type]
#     257     config=config if config else self._config,
#     258 )
#     259 model_output = (
#     260     [response.candidates[0].content]
#     261     if response.candidates and response.candidates[0].content
#     262     else []
#     263 )
#     264 automatic_function_calling_history = (
#     265     response.automatic_function_calling_history
#     266     if response.automatic_function_calling_history
#     267     else []
#     268 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\genai\models.py:5020, in Models.generate_content(self, model, contents, config)
#    5018 while remaining_remote_calls_afc > 0:
#    5019   i += 1
# -> 5020   response = self._generate_content(
#    5021       model=model, contents=contents, config=parsed_config
#    5022   )
#    5024   function_map = _extra_utils.get_function_map(parsed_config)
#    5025   if not function_map:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\genai\models.py:3832, in Models._generate_content(self, model, contents, config)
#    3829 request_dict = _common.convert_to_dict(request_dict)
#    3830 request_dict = _common.encode_unserializable_types(request_dict)
# -> 3832 response = self._api_client.request(
#    3833     'post', path, request_dict, http_options
#    3834 )
#    3836 if config is not None and getattr(
#    3837     config, 'should_return_http_response', None
#    3838 ):
#    3839   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\genai\_api_client.py:1331, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1321 def request(
#    1322     self,
#    1323     http_method: str,
#    (...)
#    1326     http_options: Optional[HttpOptionsOrDict] = None,
#    1327 ) -> SdkHttpResponse:
#    1328   http_request = self._build_request(
#    1329       http_method, path, request_dict, http_options
#    1330   )
# -> 1331   response = self._request(http_request, http_options, stream=False)
#    1332   response_body = (
#    1333       response.response_stream[0] if response.response_stream else ''
#    1334   )
#    1335   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\genai\_api_client.py:1167, in BaseApiClient._request(self, http_request, http_options, stream)
#    1164     retry = tenacity.Retrying(**retry_kwargs)
#    1165     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1167 return self._retry(self._request_once, http_request, stream)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tenacity\__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     418 retry_exc = self.retry_error_cls(fut)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tenacity\__init__.py:187, in RetryError.reraise(self)
#     185 def reraise(self) -> t.NoReturn:
#     186     if self.last_attempt.failed:
# --> 187         raise self.last_attempt.result()
#     188     raise self
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\genai\_api_client.py:1144, in BaseApiClient._request_once(self, http_request, stream)
#    1136 else:
#    1137   response = self._httpx_client.request(
#    1138       method=http_request.method,
#    1139       url=http_request.url,
#    (...)
#    1142       timeout=http_request.timeout,
#    1143   )
# -> 1144   errors.APIError.raise_for_response(response)
#    1145   return HttpResponse(
#    1146       response.headers, response if stream else [response.text]
#    1147   )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\genai\errors.py:110, in APIError.raise_for_response(cls, response)
#     108   raise ClientError(status_code, response_json, response)
#     109 elif 500 <= status_code < 600:
# --> 110   raise ServerError(status_code, response_json, response)
#     111 else:
#     112   raise cls(status_code, response_json, response)
#
# ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}

# %%
from google import genai
# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client(api_key="AIzaSyAV6da61UIyw12pOqeTdEQsENWmnjE5GaQ")

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# AI learns patterns from data to make predictions, solve problems, or generate content.

# %%
print(response)
# Out:
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text='AI learns patterns from data to make predictions, solve problems, or generate content.'
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash' prompt_feedback=None response_id='JNMEaeHaD6Hoz7IP0tDTmAw' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=16,
#   prompt_token_count=9,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=9
#     ),
#   ],
#   thoughts_token_count=772,
#   total_token_count=797
# ) automatic_function_calling_history=[] parsed=None

# %%
chat = client.chats.create(
    model="gemini-2.5-flash",  # Or "gemini-2.5-pro", etc.
    config=types.GenerateContentConfig(  # Optional: Customize temperature, etc.
        temperature=0.7,
        max_output_tokens=512
    )
)

def chatter(prompt, chat_history):
    print(prompt)

    if prompt :
        response = chat.send_message(prompt)

    output = response.candidates[0].content.parts[0].text
    return output

# %%
gr.ChatInterface(fn=chatter, type="messages").launch('share=True')
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
